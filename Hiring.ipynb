# %%
import csv
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
import time
def check_element_present(driver, url, css_selector):
    try:
        # Open the URL in the existing browser window
        driver.get(url)
        # Wait for some time to allow the page to load (adjust the sleep duration as needed)
        time.sleep(3)  # Adjust the duration based on your page loading time
        # Check if the element is present using find_elements
        elements = driver.find_elements(By.CSS_SELECTOR, css_selector)
        if elements:
            return "NO job"
        else:
            return "YES job"
    except Exception as e:
        print(f"Error: {e}")
        return str(e)
def check_elements_from_csv(input_file, output_file, css_selector_to_check):
    try:
        # Specify the path to the user profile directory
        user_profile_path = r"C:\Users\gauta\AppData\Local\Google\Chrome\User Data\Default"
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument(f"user-data-dir={user_profile_path}")
        # Create the webdriver with user profile
        chrome_service = ChromeService()  # No need to specify chromedriver executable
        driver = webdriver.Chrome(service=chrome_service, options=chrome_options)
        with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', newline='', encoding='utf-8') as outfile:
            csv_reader = csv.reader(infile)
            csv_writer = csv.writer(outfile)
            for row in csv_reader:
                url = row[0]
                print(f"Checking URL: {url}")
                result = check_element_present(driver, url, css_selector_to_check)
                print(f"Result for {url}: {result}")
                csv_writer.writerow([url, result])
        # Close the browser window when done
        driver.quit()
    except Exception as e:
        print(f"Error: {e}")
# Example usage to check if the element is present
input_file_path = "sample_input.csv"
output_file_path = "output.csv"
css_selector_to_check = "div.jobs-search-no-results-banner__image"
check_elements_from_csv(input_file_path, output_file_path, css_selector_to_check)
# Out:
# Checking URL: https://www.linkedin.com/jobs/search/?currentJobId=4336033706&f_C=64791448&geoId=92000000&keywords=POS%20Manager&origin=COMPANY_PAGE_JOBS_KEYWORD
# Result for https://www.linkedin.com/jobs/search/?currentJobId=4336033706&f_C=64791448&geoId=92000000&keywords=POS%20Manager&origin=COMPANY_PAGE_JOBS_KEYWORD: NO job
# Checking URL: https://www.linkedin.com/jobs/search/?currentJobId=4336033706&f_C=162609&geoId=92000000&keywords=POS%20Manager&origin=COMPANY_PAGE_JOBS_KEYWORD
# Result for https://www.linkedin.com/jobs/search/?currentJobId=4336033706&f_C=162609&geoId=92000000&keywords=POS%20Manager&origin=COMPANY_PAGE_JOBS_KEYWORD: YES job
# Checking URL: https://www.linkedin.com/jobs/search/?currentJobId=4336033706&f_C=2247239&geoId=92000000&keywords=POS%20Manager&origin=COMPANY_PAGE_JOBS_KEYWORD
# Result for https://www.linkedin.com/jobs/search/?currentJobId=4336033706&f_C=2247239&geoId=92000000&keywords=POS%20Manager&origin=COMPANY_PAGE_JOBS_KEYWORD: NO job
# ...
